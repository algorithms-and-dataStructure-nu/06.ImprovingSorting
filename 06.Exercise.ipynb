# %% [markdown]
# # 06 整列の改良: Improving Sorting

# %%
# 学籍番号: 
# 氏名:

# %% [markdown]
# ## 課題
# 講義で紹介したQuickSortの実装`quickSort()`を参考に、大きい順に整列する`quickSort_desc()`関数を作成し、動作を確認しなさい。
# ヒント: `pivot`の左に大きい値、右に小さい値を配置するようにする。
#
# Create a `quickSort_desc()` function that sorts in descending order, based on the quick sort implementation `quickSort()` introduced in the lecture, and verify its operation.
# Hint: Arrange larger values to the left of the `pivot` and smaller values to the right.
