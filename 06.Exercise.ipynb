# %% [markdown]
# # 06 整列の改良: Improving Sorting

# %% [markdown]
# ## 課題
# 整列済みの配列をクイックソートすると、どのようなことが起こるでしょうか。小さな配列について、手作業を行って観察しなさい。
#
# Let's consider the case of sorting an already sorted array using quicksort.
# For small arrays, perform the task manually and observe the results.

# %% [markdown]
# ## 課題
# 整列済みの配列をクイックソートする際に対して、比較の回数が配列のサイズに対してどのように変化するかを観察しなさい。
#
# Observe how the number of comparisons changes with respect to the size of the array when performing quicksort on an already sorted array.
